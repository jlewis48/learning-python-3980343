# %% [markdown]
# <a href="https://colab.research.google.com/github/jlewis48/learning-python-3980343/blob/main/helloworld_start_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Linkedin learning with Joe
#Ex file for Hello World
print("Hello world")
name = input("what is your name? ")
print("Nice to meet you", name)
# Out:
# Hello world
# what is your name? Jd
# Nice to meet you Jd
