# %% [markdown]
# <a href="https://colab.research.google.com/github/jlewis48/learning-python-3980343/blob/main/sequence_start_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# LinkedIn Learning Python course by Joe Marini
# Example file for complex types

# Sequences: Lists and Tuples
# These are -- surprise -- sequences of values
mylist = [0, 1, "two", 3.2, False]
print(len(mylist))

# (indexing) to access a member of a sequence type, use []
# print(mylist[2])
# print(mylist[-1])
# mylist[1] = 10
# print(mylist)

# add a list to another list
# another_list = [6,7,8]
# mylist = mylist + another_list
# print(mylist)

# mystr = "This is a string"
# print(mystr[2])
# print(mystr[::-1])

# use slices to get parts of a sequence
# print(mylist[::-1])

# you can use slices to reverse a sequence


# Tuples(use parenthesis instead of brackets) are like lists, but they are immutable(Unchangeable)
mytuple = (0,1,2,"three")
print(mytuple)

# Sets(use curly brackets) are also sequences, but they contain unique values ( values wont appaer twice like they can in lists) *YOU CAN'T USE INDEXES ON SETS*
myset = {1, 2, 3, 2, 4, "hey"}
print(myset)

# Set, however, can not be indexed like lists or tuples
# print(myset[0]) # this will cause an error

# Test for membership
print( 1 in myset)
print(2 in mylist)
print(3 in mytuple)
# Out:
# 5
# (0, 1, 2, 'three')
# {1, 2, 3, 4, 'hey'}
# True
# False
# False
