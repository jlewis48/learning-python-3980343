# %% [markdown]
# <a href="https://colab.research.google.com/github/jlewis48/learning-python-3980343/blob/main/loops_start_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# LinkedIn Learning Python course by Joe Marini
# Example file for working with loops


x = 0

# define a while loop
# while x < 5:
#   print(x)
#   x = x + 1

# answer = input("Should I stop?")
# while answer != "yes":
#   print(answer)
#   answer = input("Should i stop?")

# define a for loop
days =["Mon", "Tues", "Wed", "Thurs", "Fri", "Sat", "Sun"]
# for d in days:
#   print(d)


# use a for loop over a collection


# use the break and continue statements
# for d in days:
#   if (d == "Thurs"):
#     continue
#   print(d)

# using the enumerate() function to get an index and an item
for i,d in enumerate(days):
  print(i,d)
# Out:
# 0 Mon
# 1 Tues
# 2 Wed
# 3 Thurs
# 4 Fri
# 5 Sat
# 6 Sun
